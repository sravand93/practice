# %%
import pandas as pd # cmd to install is(pip install pandas)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO'

# %%
os.chdir('E:\\INSOFE\\Internship\\Data')

# %%
# reading the data from the source file path

diagnosis_data = pd.read_csv('E:\\INSOFE\\Internship\\Data\\org_data.csv')
print(diagnosis_data.shape)
# Out:
# (58509, 49)

# %%
diagnosis_data.head()
# Out:
#              V1            V2        V3        V4            V5        V6  \
# 0 -3.014600e-07  8.260300e-06 -0.000012 -0.000002 -1.438600e-06 -0.000021
# 1  2.913200e-06 -5.247700e-06  0.000003 -0.000006  2.778900e-06 -0.000004
# 2 -2.951700e-06 -3.184000e-06 -0.000016 -0.000001 -1.575300e-06  0.000017
# 3 -1.322600e-06  8.820100e-06 -0.000016 -0.000005 -7.282900e-07  0.000004
# 4 -6.836600e-08  5.666300e-07 -0.000026 -0.000006 -7.940600e-07  0.000013
#
#          V7        V8        V9       V10 ...       V40     V41     V42  \
# 0  0.031718  0.031710  0.031721 -0.032963 ...  -0.63308  2.9646  8.1198
# 1  0.030804  0.030810  0.030806 -0.033520 ...  -0.59314  7.6252  6.1690
# 2  0.032877  0.032880  0.032896 -0.029834 ...  -0.63252  2.7784  5.3017
# 3  0.029410  0.029401  0.029417 -0.030156 ...  -0.62289  6.5534  6.2606
# 4  0.030119  0.030119  0.030145 -0.031393 ...  -0.63010  4.5155  9.5231
#
#       V43     V44     V45     V46     V47     V48  V49
# ...

# %%
#finding if there are any missing values

diagnosis_data.isnull().any().sum()
# Out:
# 0

# %%
diagnosis_data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41',
#        'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49'],
#       dtype='object')

# %%
num_data = diagnosis_data.iloc[:,0:48].copy()

# %%
num_data.head()
# Out:
#              V1            V2        V3        V4            V5        V6  \
# 0 -3.014600e-07  8.260300e-06 -0.000012 -0.000002 -1.438600e-06 -0.000021
# 1  2.913200e-06 -5.247700e-06  0.000003 -0.000006  2.778900e-06 -0.000004
# 2 -2.951700e-06 -3.184000e-06 -0.000016 -0.000001 -1.575300e-06  0.000017
# 3 -1.322600e-06  8.820100e-06 -0.000016 -0.000005 -7.282900e-07  0.000004
# 4 -6.836600e-08  5.666300e-07 -0.000026 -0.000006 -7.940600e-07  0.000013
#
#          V7        V8        V9       V10   ...        V39      V40     V41  \
# 0  0.031718  0.031710  0.031721 -0.032963   ...     6.0168 -0.63308  2.9646
# 1  0.030804  0.030810  0.030806 -0.033520   ...     3.6048 -0.59314  7.6252
# 2  0.032877  0.032880  0.032896 -0.029834   ...     5.8007 -0.63252  2.7784
# 3  0.029410  0.029401  0.029417 -0.030156   ...    23.3960 -0.62289  6.5534
# 4  0.030119  0.030119  0.030145 -0.031393   ...     5.0582 -0.63010  4.5155
#
#       V42     V43     V44     V45     V46     V47     V48
# ...

# %%
# here the varaible V49 is the class variable and that has to be converted to categorical

diagnosis_data.V49 = diagnosis_data['V49'].astype('category')

# %%
diagnosis_data.V49.value_counts()
# Out:
# 11    5319
# 10    5319
# 9     5319
# 8     5319
# 7     5319
# 6     5319
# 5     5319
# 4     5319
# 3     5319
# 2     5319
# 1     5319
# Name: V49, dtype: int64

# %%
plt.plot(diagnosis_data.V1)

# %%
plt.plot(diagnosis_data.V2)

# %%
plt.plot(diagnosis_data.V3,'r')

# %%
# to find the summary of the data set

diagnosis_data.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  58509.000000  5.850900e+04  5.850900e+04  58509.000000  5.850900e+04
# mean      -0.000003  1.439648e-06  1.412013e-06     -0.000001  1.351239e-06
# std        0.000072  5.555429e-05  2.353009e-04      0.000063  5.660943e-05
# min       -0.013721 -5.414400e-03 -1.358000e-02     -0.012787 -8.355900e-03
# 25%       -0.000007 -1.444400e-05 -7.239600e-05     -0.000005 -1.475300e-05
# 50%       -0.000003  8.804600e-07  5.137700e-07     -0.000001  7.540200e-07
# 75%        0.000002  1.877700e-05  7.520000e-05      0.000004  1.906200e-05
# max        0.005784  4.525300e-03  5.237700e-03      0.001453  8.245100e-04
#
#                  V6            V7            V8            V9           V10  \
# count  5.850900e+04  58509.000000  58509.000000  58509.000000  58509.000000
# mean  -2.654483e-07      0.001915      0.001913      0.001912     -0.011897
# ...

# %%
# finding correlation between the variables

diagnosis_data.corr()
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# V1   1.000000  0.574463  0.268946  0.272271  0.098113  0.099363  0.051068
# V2   0.574463  1.000000  0.188993  0.261633  0.198154  0.112018  0.038799
# V3   0.268946  0.188993  1.000000  0.069828  0.076619  0.040039 -0.014772
# V4   0.272271  0.261633  0.069828  1.000000  0.610378  0.251760 -0.016348
# V5   0.098113  0.198154  0.076619  0.610378  1.000000  0.178844  0.006462
# V6   0.099363  0.112018  0.040039  0.251760  0.178844  1.000000 -0.002451
# V7   0.051068  0.038799 -0.014772 -0.016348  0.006462 -0.002451  1.000000
# V8   0.050196  0.037278 -0.015060 -0.016747  0.006161 -0.002622  0.999999
# V9   0.048455  0.036054 -0.021511 -0.017196  0.005666 -0.002880  0.999976
# V10  0.024870  0.039779 -0.006834  0.008960  0.043546  0.014400  0.803820
# V11  0.024787  0.039611 -0.006899  0.008441  0.042696  0.014248  0.803844
# V12  0.024450  0.039232 -0.007036  0.007585  0.042090  0.010846  0.803887
# ...

# %%
sns.heatmap(diagnosis_data.corr(),vmax =True,square = True)

# %% [markdown]
# ### Performing PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
num_data = scale(num_data)

# %%
pca_for_data = PCA(n_components=0.95,svd_solver="full")

# %%
pca_for_data.fit(num_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=0.95, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
pca_for_data.explained_variance_ratio_
# Out:
# array([ 0.18769769,  0.13658891,  0.08883692,  0.07701402,  0.06544054,
#         0.05693698,  0.05556326,  0.03711397,  0.03083485,  0.02976648,
#         0.0275531 ,  0.02721189,  0.02377104,  0.0204692 ,  0.01761454,
#         0.01606814,  0.01500631,  0.01360699,  0.01149766,  0.01045256,
#         0.00861283])

# %%
pca_for_data.explained_variance_
# Out:
# array([ 9.00948915,  6.55626759,  4.264172  ,  3.696673  ,  3.14114571,
#         2.73297509,  2.66703645,  1.78147043,  1.48007276,  1.42879121,
#         1.322549  ,  1.30617085,  1.1410097 ,  0.98252161,  0.8454977 ,
#         0.77127086,  0.72030298,  0.65313528,  0.5518877 ,  0.50172271,
#         0.41341585])

# %%
import numpy as np

# %%
#explains cummulative variance
var_pca = np.cumsum(np.round(pca_for_data.explained_variance_ratio_,decimals=4)*100)

# %%
print(var_pca)
# Out:
# [ 18.77  32.43  41.31  49.01  55.55  61.24  66.8   70.51  73.59  76.57
#   79.33  82.05  84.43  86.48  88.24  89.85  91.35  92.71  93.86  94.91
#   95.77]

# %%
plt.plot(var_pca)

# %%
pca_data = pca_for_data.transform(num_data)

# %%
pca_data.shape
# Out:
# (58509, 26)

# %%
pca_for_data.score
# Out:
# <bound method PCA.score of PCA(copy=True, iterated_power='auto',
#   n_components=array([[ 0.04227,  0.12278, ..., -0.57108, -0.603  ],
#        [ 0.0871 , -0.12038, ..., -0.85561, -0.88648],
#        ...,
#        [-0.01545,  0.58555, ...,  1.45219,  1.44441],
#        [-0.07698,  0.91478, ...,  1.0096 ,  1.06642]]),
#   random_state=None, svd_solver='auto', tol=0.0, whiten=False)>

# %%
X = diagnosis_data.iloc[:,:-1]
Y = diagnosis_data.V49

# %% [markdown]
# ## Test,train and validation split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.20,random_state = 102)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size = 0.20,random_state=102)

# %%
x_train.shape,x_test.shape,x_val.shape
# Out:
# ((37445, 48), (11702, 48), (9362, 48))

# %%
#standardizing the numeric values

from sklearn import preprocessing
std = preprocessing.StandardScaler()
std.fit(x_train)
x_train = std.transform(x_train)
x_test = std.transform(x_test)
x_val = std.transform(x_val)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()
log_model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
logistic_preds =log_model.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,logistic_preds))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.91      0.94      0.92      1090
#           2       0.60      0.53      0.56      1030
#           3       0.60      0.64      0.62      1109
#           4       0.78      0.74      0.76      1066
#           5       0.55      0.60      0.58      1054
#           6       0.63      0.70      0.66      1032
#           7       1.00      1.00      1.00      1039
#           8       0.82      0.69      0.75      1108
#           9       0.67      0.56      0.61      1058
#          10       0.65      0.80      0.72      1021
#          11       1.00      1.00      1.00      1095
#
# avg / total       0.75      0.75      0.74     11702

# %%
from sklearn import metrics

# %%
print("Accuracy", metrics.accuracy_score(y_test,logistic_preds))
print("Recall  ", metrics.recall_score(y_test,logistic_preds,average="macro"))
print("precision",metrics.precision_score(y_test,logistic_preds,average="macro"))
# Out:
# Accuracy 0.745513587421
# Recall   0.744752735962
# precision 0.74740042748
