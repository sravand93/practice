# %%
#loading necessary libraries

import pandas as pd
import numpy as np
import os
import json

# %%
os.chdir("E:\INSOFE\ip")

# %%
from pandas.io.json import json_normalize

# %%
da = open("Total MVA (MVA).json")

# %%
data = pd.read_json("Total MVA (MVA).json")

# %%
print(json_normalize(da))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-30c68c71cd99> in <module>()
# ----> 1 print(json_normalize(da))
#
# E:\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     181
#     182     if record_path is None:
# --> 183         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     184             # naive normalization, this is idempotent for flat records
#     185             # and potentially will inflate the data considerably for
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
dat = lst = open("Total MVA (MVA).json", "r").readlines()

# %%
print(json_normalize(lst))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-c7a8f70017aa> in <module>()
# ----> 1 print(json_normalize(lst))
#
# E:\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     181
#     182     if record_path is None:
# --> 183         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     184             # naive normalization, this is idempotent for flat records
#     185             # and potentially will inflate the data considerably for
#
# E:\Anaconda3\lib\site-packages\pandas\compat\__init__.py in itervalues(obj, **kw)
#     182
#     183     def itervalues(obj, **kw):
# --> 184         return iter(obj.values(**kw))
#     185
#     186     next = next
#
# AttributeError: 'str' object has no attribute 'values'

# %%
df = pd.DataFrame(dat)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-80dbe2efdfd0> in <module>()
# ----> 1 dat.T
#
# AttributeError: 'list' object has no attribute 'T'

# %%
df = pd.DataFrame.from_dict(json_normalize(dat),orient='columns')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c94e7bc4f8ff> in <module>()
# ----> 1 df = pd.DataFrame.from_dict(json_normalize(dat),orient='columns')
#
# E:\Anaconda3\lib\site-packages\pandas\io\json\normalize.py in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     181
#     182     if record_path is None:
# --> 183         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     184             # naive normalization, this is idempotent for flat records
#     185             # and potentially will inflate the data considerably for
#
# E:\Anaconda3\lib\site-packages\pandas\compat\__init__.py in itervalues(obj, **kw)
#     182
#     183     def itervalues(obj, **kw):
# --> 184         return iter(obj.values(**kw))
#     185
#     186     next = next
#
# AttributeError: 'str' object has no attribute 'values'

# %%
df.head()
# Out:
#                                            2018-02-01  \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.1, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# 60  {'06:08:03   ': 0.1, '07:08:52   ': 0.60000000...
#
#                                            2018-03-01  \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.2, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# 60  {'06:08:03   ': 0.1, '07:08:52   ': 0.70000000...
#
#                                            2018-04-01  \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.2, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc (pandas\_libs\index.c:10160)()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc (pandas\_libs\index.c:9992)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas\_libs\hashtable.c:13913)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas\_libs\hashtable.c:13857)()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ...
