# %%
#loading necessary libraries

import pandas as pd
import numpy as np
import os
import json

# %%
os.chdir("E:\INSOFE\ip")

# %%
js_file = open("Total MVA (MVA).json")

# %%
df = json.load(js_file)

# %%
df
# Out:
# {'02-01-2018  ': {'10': {'06:08:03   ': 0.0,
#    '06:18:02   ': 0.0,
#    '06:28:01   ': 0.2,
#    '06:38:04   ': 0.2,
#    '06:48:01   ': 0.1,
#    '06:58:35   ': 0.1,
#    '07:08:52   ': 0.2,
#    '07:18:35   ': 0.3,
#    '07:29:11   ': 0.5,
#    '07:39:04   ': 0.7,
#    '07:48:53   ': 0.9,
#    '07:58:43   ': 1.1,
#    '08:08:48   ': 1.3,
#    '08:18:45   ': 1.5,
#    '08:28:35   ': 1.7,
#    '08:38:40   ': 1.9,
#    '08:48:38   ': 2.1,
#    '08:58:34   ': 2.3,
#    '09:08:44   ': 2.5,
#    '09:18:37   ': 2.7,
#    '09:28:46   ': 2.8,
#    '09:38:52   ': 3.0,
#    '09:48:54   ': 3.1,
#    '09:58:29   ': 3.3,
#    '10:08:29   ': 3.4,
#    '10:19:04   ': 3.5,
#    '10:28:56   ': 3.6,
#    '10:38:58   ': 3.8,
#    '10:48:43   ': 3.8,
#    '10:58:43   ': 3.9,
#    '11:08:43   ': 3.9,
#    '11:18:43   ': 4.1,
#    '11:39:13   ': 3.9,
#    '11:48:50   ': 3.8,
#    '11:59:00   ': 2.5,
#    '12:08:31   ': 3.3,
#    '12:18:48   ': 2.5,
#    '12:28:37   ': 2.1,
#    '12:38:59   ': 3.5,
# ...

# %%
df_data.head()
# Out:
#                                          02-01-2018    \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.1, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# 60  {'06:08:03   ': 0.1, '07:08:52   ': 0.6, '08:0...
#
#                                          03-01-2018    \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.2, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# 60  {'06:08:03   ': 0.1, '07:08:52   ': 0.7, '08:0...
#
#                                          04-01-2018    \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.2, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# ...

# %%
data = pd.read_json('Total MVA (MVA).json')

# %%
data.head()
# Out:
#                                            2018-02-01  \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.1, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# 60  {'06:08:03   ': 0.1, '07:08:52   ': 0.60000000...
#
#                                            2018-03-01  \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.2, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# 60  {'06:08:03   ': 0.1, '07:08:52   ': 0.70000000...
#
#                                            2018-04-01  \
# 10  {'06:08:03   ': 0.0, '06:18:02   ': 0.0, '06:2...
# 15  {'06:08:03   ': 0.0, '06:23:02   ': 0.1, '06:3...
# 30  {'06:08:03   ': 0.1, '06:38:04   ': 0.2, '07:0...
# 5   {'06:08:03   ': 0.0, '06:13:01   ': 0.0, '06:1...
# ...

# %%
df['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-ca5dafdde3d0> in <module>()
# ----> 1 df['5 ']
#
# KeyError: '5 '
